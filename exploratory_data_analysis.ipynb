# %%
#import the useful libraries.
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# Read the data set of "Marketing Analysis" in data.
data= pd.read_csv("Mobile Device Data for Assignment 2.csv")

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.describe()
# Out:
#        Release Year     Model ID  ...  Mass (grams)  Pixel Density (per inch)
# count   3162.000000  3162.000000  ...   3162.000000               3162.000000
# mean    2008.516867  1581.500000  ...      0.036614                  0.333562
# std        3.757541   912.935102  ...      0.054600                  0.159551
# min     1989.000000     1.000000  ...      0.000000                  0.000000
# 25%     2006.500000   791.250000  ...      0.013793                  0.212519
# 50%     2009.250000  1581.500000  ...      0.018966                  0.288743
# 75%     2011.666667  2371.750000  ...      0.031897                  0.452802
# max     2012.916667  3162.000000  ...      1.000000                  1.000000
#
# [8 rows x 14 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3162 entries, 0 to 3161
# Data columns (total 16 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Model                     3162 non-null   object
#  1   Release Date              3162 non-null   object
#  2   Release Year              3162 non-null   float64
#  3   Model ID                  3162 non-null   int64
#  4   RAM Capacity (Mb)         3162 non-null   float64
#  5   Storage (Mb)              3162 non-null   float64
#  6   CPU Clock (MHz)           3162 non-null   float64
#  7   Display Diagonal (in)     3162 non-null   float64
#  8   Display Width(px)         3162 non-null   float64
#  9   Display Length(px)        3162 non-null   float64
#  10  Width (mm)                3162 non-null   float64
#  11  Length (mm)               3162 non-null   float64
#  12  Depth (mm)                3162 non-null   float64
# ...

# %%
# Checking the missing values
data.isnull().sum()
# Out:
# Model                       0
# Release Date                0
# Release Year                0
# Model ID                    0
# RAM Capacity (Mb)           0
# Storage (Mb)                0
# CPU Clock (MHz)             0
# Display Diagonal (in)       0
# Display Width(px)           0
# Display Length(px)          0
# Width (mm)                  0
# Length (mm)                 0
# Depth (mm)                  0
# Volume (cubic cm)           0
# Mass (grams)                0
# Pixel Density (per inch)    0
# dtype: int64

# %%
# Creating a matrix using age, salry, balance as rows and columns
data.corr()

#plot the correlation matrix of salary, balance and age in data dataframe.
plt.figure(figsize=(10, 10))
sns.heatmap(data.corr(), annot=True, cmap = 'Reds')
plt.show()

# %%
data.columns = data.columns.str.strip().str.lower().str.replace(' ', '_').str.replace('(', '').str.replace(')', '')
data.head()
# Out:
#                                       model  ... pixel_density_per_inch
# 0                  Psion Organiser II LZ 64  ...               0.000000
# 1          Hewlett-Packard 95LX (HP Jaguar)  ...               0.030793
# 2                            Psion Series 3  ...               0.035336
# 3  Hewlett-Packard 95LX 1MB RAM (HP Jaguar)  ...               0.030793
# 4                           Psion Series 3a  ...               0.129985
#
# [5 rows x 16 columns]

# %%
# #fig, axs = plt.subplots(nrows=4, ncols=4)  
# plt.figure(figsize=(32, 32))

# for i in range(1, data.shape[1] + 1):
#   #plt.figure(figsize=(16, 16))
#   plt.subplot(16, 1, i)
#   f = plt.gca()
#   vals = np.size(data.iloc[:, i-1].unique())
#   # plt.tight_layout()
#   plt.hist(data.iloc[:, i-1], bins=vals, color='red')

# %%
data['release_year'] = data['release_year'].astype(int)
data.drop(['model','release_date','model_id'], axis = 1, inplace=True)

# %%
# fig, axs = plt.subplots(nrows=4, ncols=4)  
plt.figure(figsize=(32, 32))

for i in range(1, data.shape[1] + 1):
  #plt.figure(figsize=(16, 16))
  plt.subplot(16, 1, i)
  f = plt.gca()
  vals = np.size(data.iloc[:, i-1].unique())
  # plt.tight_layout()
  plt.hist(data.iloc[:, i-1], bins=vals, color='red')

# %%
#data = data.set_index('release_year')
data.head()
# Out:
#    release_year  ram_capacity_mb  ...  mass_grams  pixel_density_per_inch
# 0          1989         0.000000  ...    0.044181                0.000000
# 1          1991         0.000214  ...    0.053879                0.030793
# 2          1991         0.000092  ...    0.044181                0.035336
# 3          1992         0.000458  ...    0.053879                0.030793
# 4          1993         0.000214  ...    0.046336                0.129985
#
# [5 rows x 13 columns]

# %%
# y = [data['ram_capacity_mb'], data['storage_mb'], data['cpu_clock_mhz'],
#        data['display_diagonal_in'], data['display_widthpx'], data['display_lengthpx'],
#        data['width_mm'], data['length_mm'], data['depth_mm'], data['volume_cubic_cm'], data['mass_grams'],
#        data['pixel_density_per_inch']]
# x = data['release_year']

# for i in range(len(y)):
#   plt.figure()
#   plt.scatter(x,y[i], c='red')
# # data.columns[[2]]

# %%
count=1
plt.subplots(figsize=(20, 20))
for i in data.columns[1:]:
  plt.subplot(4,4,count)
  sns.scatterplot(data["release_year"],data[i], color = 'red' )
  count+=1
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# ...

# %%
print(type(data.columns))
print(type(data))
data.columns[[2]]
# Out:
# <class 'pandas.core.indexes.base.Index'>
# <class 'pandas.core.frame.DataFrame'>
# Index(['storage_mb'], dtype='object')

# %%
count=1
plt.subplots(figsize=(25, 25))
for i, col in enumerate(data.columns[0:]):
    plt.subplot(5,3,count)
    sns.histplot(data[col], color = 'red')
    count+=1
plt.show()

# %%
count=1
plt.subplots(figsize=(25, 25))
for i, col in enumerate(data.columns[0:]):
    plt.subplot(5,3,count)
    sns.distplot(data[col], color = 'red')
    count+=1
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...
